# %% [markdown]
# # **Task 1: Implement ChaCha20 Encryption and Decryption**
# - Implement ChaCha20 encryption and decryption using Python.
# - Encrypt a given plaintext using a fixed key and nonce.
# - Decrypt the ciphertext to verify correctness.
# - Compare encryption and decryption times for different plaintext sizes.

# %%
# !pip install pycryptodome

import time
from Crypto.Cipher import ChaCha20
from Crypto.Random import get_random_bytes


def encrypt_chacha20(plaintext, key, nonce): #create a function
  cipher = ChaCha20.new(key=key, nonce=nonce)
  ciphertext = cipher.encrypt(plaintext)
  return ciphertext


def decrypt_chacha20(ciphertext, key, nonce):
  cipher = ChaCha20.new(key=key, nonce=nonce)
  plaintext = cipher.decrypt(ciphertext)
  return plaintext


# Fixed key and nonce for demonstration
key = get_random_bytes(32)
nonce = get_random_bytes(12)

# Example plaintext
plaintext = b"This is a secret message."

# Encrypt the plaintext
start_time = time.time()
ciphertext = encrypt_chacha20(plaintext, key, nonce)
end_time = time.time()
encryption_time = end_time - start_time
print("Encryption time:", encryption_time)


# Decrypt the ciphertext
start_time = time.time()
decrypted_plaintext = decrypt_chacha20(ciphertext, key, nonce)
end_time = time.time()
decryption_time = end_time - start_time
print("Decryption time:", decryption_time)

# Verify correctness
if decrypted_plaintext == plaintext:
  print("Encryption and decryption successful.")
else:
  print("Encryption and decryption failed.")

# Compare encryption and decryption times for different plaintext sizes
plaintext_sizes = [1024, 4096, 16384, 65536]
for size in plaintext_sizes:
  plaintext = get_random_bytes(size)
  start_time = time.time()
  ciphertext = encrypt_chacha20(plaintext, key, nonce)
  end_time = time.time()
  encryption_time = end_time - start_time

  start_time = time.time()
  decrypted_plaintext = decrypt_chacha20(ciphertext, key, nonce)
  end_time = time.time()
  decryption_time = end_time - start_time

  print(f"Plaintext size: {size} bytes")
  print(f"Encryption time: {encryption_time:.6f} seconds")
  print(f"Decryption time: {decryption_time:.6f} seconds")
# Out:
# Collecting pycryptodome
#   Downloading pycryptodome-3.22.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Downloading pycryptodome-3.22.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 16.9 MB/s eta 0:00:00
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.22.0
# Encryption time: 0.0031681060791015625
# Decryption time: 0.00020647048950195312
# Encryption and decryption successful.
# Plaintext size: 1024 bytes
# Encryption time: 0.000063 seconds
# Decryption time: 0.000030 seconds
# Plaintext size: 4096 bytes
# Encryption time: 0.000045 seconds
# Decryption time: 0.000054 seconds
# Plaintext size: 16384 bytes
# Encryption time: 0.000121 seconds
# Decryption time: 0.000165 seconds
# Plaintext size: 65536 bytes
# Encryption time: 0.000427 seconds
# Decryption time: 0.000414 seconds

# %% [markdown]
# # **Task 2: Effect of Key Variations**
# - Encrypt a fixed plaintext using different keys with minor variations (flipping bits).
# - Analyze the ciphertexts to observe the avalanche effect.
# - Measure the bitwise differences between different ciphertexts.

# %%
from Crypto.Cipher import ChaCha20
from Crypto.Random import get_random_bytes

def flip_bit(key, bit_index):
    """Flips the bit at the specified index in the key."""
    key_list = list(key)  # Convert bytes to list of integers
    byte_index = bit_index // 8
    bit_offset = bit_index % 8
    key_list[byte_index] ^= (1 << bit_offset)  # Flip the bit using XOR
    return bytes(key_list)  # Convert back to bytes

# Generate a random key and nonce
key = get_random_bytes(32)
nonce = get_random_bytes(12)

# Fixed plaintext
plaintext = b"This is a secret message."

# Encrypt with the original key
ciphertext_original = ChaCha20.new(key=key, nonce=nonce).encrypt(plaintext)

# Iterate through key bits and flip them
for bit_index in range(len(key) * 8):
    modified_key = flip_bit(key, bit_index)
    ciphertext_modified = ChaCha20.new(key=modified_key, nonce=nonce).encrypt(plaintext)

    # Calculate bitwise differences
    diff_count = sum(bin(a ^ b).count('1') for a, b in zip(ciphertext_original, ciphertext_modified))

    print(f"Flipped bit index: {bit_index}, Bitwise difference: {diff_count}")
# Out:
# Flipped bit index: 0, Bitwise difference: 100
# Flipped bit index: 1, Bitwise difference: 91
# Flipped bit index: 2, Bitwise difference: 115
# Flipped bit index: 3, Bitwise difference: 110
# Flipped bit index: 4, Bitwise difference: 104
# Flipped bit index: 5, Bitwise difference: 103
# Flipped bit index: 6, Bitwise difference: 100
# Flipped bit index: 7, Bitwise difference: 106
# Flipped bit index: 8, Bitwise difference: 108
# Flipped bit index: 9, Bitwise difference: 95
# Flipped bit index: 10, Bitwise difference: 96
# Flipped bit index: 11, Bitwise difference: 102
# Flipped bit index: 12, Bitwise difference: 94
# Flipped bit index: 13, Bitwise difference: 102
# Flipped bit index: 14, Bitwise difference: 99
# Flipped bit index: 15, Bitwise difference: 100
# Flipped bit index: 16, Bitwise difference: 102
# Flipped bit index: 17, Bitwise difference: 112
# Flipped bit index: 18, Bitwise difference: 99
# Flipped bit index: 19, Bitwise difference: 91
# Flipped bit index: 20, Bitwise difference: 100
# Flipped bit index: 21, Bitwise difference: 101
# Flipped bit index: 22, Bitwise difference: 96
# Flipped bit index: 23, Bitwise difference: 104
# Flipped bit index: 24, Bitwise difference: 99
# Flipped bit index: 25, Bitwise difference: 106
# Flipped bit index: 26, Bitwise difference: 97
# Flipped bit index: 27, Bitwise difference: 106
# Flipped bit index: 28, Bitwise difference: 100
# Flipped bit index: 29, Bitwise difference: 106
# Flipped bit index: 30, Bitwise difference: 93
# Flipped bit index: 31, Bitwise difference: 101
# Flipped bit index: 32, Bitwise difference: 91
# Flipped bit index: 33, Bitwise difference: 110
# Flipped bit index: 34, Bitwise difference: 92
# Flipped bit index: 35, Bitwise difference: 101
# Flipped bit index: 36, Bitwise difference: 90
# Flipped bit index: 37, Bitwise difference: 99
# Flipped bit index: 38, Bitwise difference: 108
# Flipped bit index: 39, Bitwise difference: 102
# Flipped bit index: 40, Bitwise difference: 109
# Flipped bit index: 41, Bitwise difference: 93
# Flipped bit index: 42, Bitwise difference: 105
# Flipped bit index: 43, Bitwise difference: 95
# Flipped bit index: 44, Bitwise difference: 97
# Flipped bit index: 45, Bitwise difference: 102
# Flipped bit index: 46, Bitwise difference: 96
# Flipped bit index: 47, Bitwise difference: 99
# Flipped bit index: 48, Bitwise difference: 96
# Flipped bit index: 49, Bitwise difference: 96
# Flipped bit index: 50, Bitwise difference: 113
# Flipped bit index: 51, Bitwise difference: 95
# Flipped bit index: 52, Bitwise difference: 96
# Flipped bit index: 53, Bitwise difference: 100
# Flipped bit index: 54, Bitwise difference: 97
# Flipped bit index: 55, Bitwise difference: 100
# Flipped bit index: 56, Bitwise difference: 98
# Flipped bit index: 57, Bitwise difference: 118
# Flipped bit index: 58, Bitwise difference: 103
# Flipped bit index: 59, Bitwise difference: 96
# Flipped bit index: 60, Bitwise difference: 99
# Flipped bit index: 61, Bitwise difference: 112
# Flipped bit index: 62, Bitwise difference: 92
# Flipped bit index: 63, Bitwise difference: 104
# Flipped bit index: 64, Bitwise difference: 108
# Flipped bit index: 65, Bitwise difference: 88
# Flipped bit index: 66, Bitwise difference: 109
# Flipped bit index: 67, Bitwise difference: 94
# Flipped bit index: 68, Bitwise difference: 105
# Flipped bit index: 69, Bitwise difference: 103
# Flipped bit index: 70, Bitwise difference: 108
# Flipped bit index: 71, Bitwise difference: 89
# Flipped bit index: 72, Bitwise difference: 108
# Flipped bit index: 73, Bitwise difference: 108
# Flipped bit index: 74, Bitwise difference: 98
# Flipped bit index: 75, Bitwise difference: 97
# Flipped bit index: 76, Bitwise difference: 107
# Flipped bit index: 77, Bitwise difference: 93
# Flipped bit index: 78, Bitwise difference: 98
# Flipped bit index: 79, Bitwise difference: 93
# Flipped bit index: 80, Bitwise difference: 99
# Flipped bit index: 81, Bitwise difference: 100
# Flipped bit index: 82, Bitwise difference: 104
# Flipped bit index: 83, Bitwise difference: 84
# Flipped bit index: 84, Bitwise difference: 106
# Flipped bit index: 85, Bitwise difference: 97
# Flipped bit index: 86, Bitwise difference: 81
# Flipped bit index: 87, Bitwise difference: 94
# Flipped bit index: 88, Bitwise difference: 108
# Flipped bit index: 89, Bitwise difference: 103
# Flipped bit index: 90, Bitwise difference: 111
# Flipped bit index: 91, Bitwise difference: 93
# Flipped bit index: 92, Bitwise difference: 96
# Flipped bit index: 93, Bitwise difference: 104
# Flipped bit index: 94, Bitwise difference: 101
# Flipped bit index: 95, Bitwise difference: 98
# Flipped bit index: 96, Bitwise difference: 99
# Flipped bit index: 97, Bitwise difference: 99
# Flipped bit index: 98, Bitwise difference: 92
# Flipped bit index: 99, Bitwise difference: 90
# Flipped bit index: 100, Bitwise difference: 94
# Flipped bit index: 101, Bitwise difference: 107
# Flipped bit index: 102, Bitwise difference: 110
# Flipped bit index: 103, Bitwise difference: 119
# Flipped bit index: 104, Bitwise difference: 101
# Flipped bit index: 105, Bitwise difference: 104
# Flipped bit index: 106, Bitwise difference: 89
# Flipped bit index: 107, Bitwise difference: 103
# Flipped bit index: 108, Bitwise difference: 97
# Flipped bit index: 109, Bitwise difference: 97
# Flipped bit index: 110, Bitwise difference: 105
# Flipped bit index: 111, Bitwise difference: 95
# Flipped bit index: 112, Bitwise difference: 98
# Flipped bit index: 113, Bitwise difference: 92
# Flipped bit index: 114, Bitwise difference: 105
# Flipped bit index: 115, Bitwise difference: 104
# Flipped bit index: 116, Bitwise difference: 113
# Flipped bit index: 117, Bitwise difference: 107
# Flipped bit index: 118, Bitwise difference: 93
# Flipped bit index: 119, Bitwise difference: 88
# Flipped bit index: 120, Bitwise difference: 92
# Flipped bit index: 121, Bitwise difference: 102
# Flipped bit index: 122, Bitwise difference: 103
# Flipped bit index: 123, Bitwise difference: 91
# Flipped bit index: 124, Bitwise difference: 102
# Flipped bit index: 125, Bitwise difference: 106
# Flipped bit index: 126, Bitwise difference: 92
# Flipped bit index: 127, Bitwise difference: 103
# Flipped bit index: 128, Bitwise difference: 97
# Flipped bit index: 129, Bitwise difference: 103
# Flipped bit index: 130, Bitwise difference: 108
# Flipped bit index: 131, Bitwise difference: 96
# Flipped bit index: 132, Bitwise difference: 85
# Flipped bit index: 133, Bitwise difference: 99
# Flipped bit index: 134, Bitwise difference: 109
# Flipped bit index: 135, Bitwise difference: 93
# Flipped bit index: 136, Bitwise difference: 102
# Flipped bit index: 137, Bitwise difference: 93
# Flipped bit index: 138, Bitwise difference: 103
# Flipped bit index: 139, Bitwise difference: 91
# Flipped bit index: 140, Bitwise difference: 115
# Flipped bit index: 141, Bitwise difference: 115
# Flipped bit index: 142, Bitwise difference: 102
# Flipped bit index: 143, Bitwise difference: 101
# Flipped bit index: 144, Bitwise difference: 100
# Flipped bit index: 145, Bitwise difference: 107
# Flipped bit index: 146, Bitwise difference: 106
# Flipped bit index: 147, Bitwise difference: 100
# Flipped bit index: 148, Bitwise difference: 88
# Flipped bit index: 149, Bitwise difference: 98
# Flipped bit index: 150, Bitwise difference: 109
# Flipped bit index: 151, Bitwise difference: 110
# Flipped bit index: 152, Bitwise difference: 93
# Flipped bit index: 153, Bitwise difference: 97
# Flipped bit index: 154, Bitwise difference: 105
# Flipped bit index: 155, Bitwise difference: 98
# Flipped bit index: 156, Bitwise difference: 78
# Flipped bit index: 157, Bitwise difference: 114
# Flipped bit index: 158, Bitwise difference: 102
# Flipped bit index: 159, Bitwise difference: 106
# Flipped bit index: 160, Bitwise difference: 99
# Flipped bit index: 161, Bitwise difference: 96
# Flipped bit index: 162, Bitwise difference: 103
# Flipped bit index: 163, Bitwise difference: 90
# Flipped bit index: 164, Bitwise difference: 100
# Flipped bit index: 165, Bitwise difference: 97
# Flipped bit index: 166, Bitwise difference: 94
# Flipped bit index: 167, Bitwise difference: 94
# Flipped bit index: 168, Bitwise difference: 94
# Flipped bit index: 169, Bitwise difference: 96
# Flipped bit index: 170, Bitwise difference: 96
# Flipped bit index: 171, Bitwise difference: 101
# Flipped bit index: 172, Bitwise difference: 95
# Flipped bit index: 173, Bitwise difference: 97
# Flipped bit index: 174, Bitwise difference: 103
# Flipped bit index: 175, Bitwise difference: 95
# Flipped bit index: 176, Bitwise difference: 98
# Flipped bit index: 177, Bitwise difference: 103
# Flipped bit index: 178, Bitwise difference: 101
# Flipped bit index: 179, Bitwise difference: 102
# Flipped bit index: 180, Bitwise difference: 97
# Flipped bit index: 181, Bitwise difference: 103
# Flipped bit index: 182, Bitwise difference: 102
# Flipped bit index: 183, Bitwise difference: 102
# Flipped bit index: 184, Bitwise difference: 90
# Flipped bit index: 185, Bitwise difference: 104
# Flipped bit index: 186, Bitwise difference: 102
# Flipped bit index: 187, Bitwise difference: 92
# Flipped bit index: 188, Bitwise difference: 112
# Flipped bit index: 189, Bitwise difference: 95
# Flipped bit index: 190, Bitwise difference: 99
# Flipped bit index: 191, Bitwise difference: 113
# Flipped bit index: 192, Bitwise difference: 93
# Flipped bit index: 193, Bitwise difference: 102
# Flipped bit index: 194, Bitwise difference: 93
# Flipped bit index: 195, Bitwise difference: 96
# Flipped bit index: 196, Bitwise difference: 101
# Flipped bit index: 197, Bitwise difference: 88
# Flipped bit index: 198, Bitwise difference: 106
# Flipped bit index: 199, Bitwise difference: 112
# Flipped bit index: 200, Bitwise difference: 103
# Flipped bit index: 201, Bitwise difference: 99
# Flipped bit index: 202, Bitwise difference: 105
# Flipped bit index: 203, Bitwise difference: 70
# Flipped bit index: 204, Bitwise difference: 95
# Flipped bit index: 205, Bitwise difference: 110
# Flipped bit index: 206, Bitwise difference: 92
# Flipped bit index: 207, Bitwise difference: 96
# Flipped bit index: 208, Bitwise difference: 106
# Flipped bit index: 209, Bitwise difference: 102
# Flipped bit index: 210, Bitwise difference: 97
# Flipped bit index: 211, Bitwise difference: 109
# Flipped bit index: 212, Bitwise difference: 87
# Flipped bit index: 213, Bitwise difference: 104
# Flipped bit index: 214, Bitwise difference: 111
# Flipped bit index: 215, Bitwise difference: 98
# Flipped bit index: 216, Bitwise difference: 100
# Flipped bit index: 217, Bitwise difference: 98
# Flipped bit index: 218, Bitwise difference: 99
# Flipped bit index: 219, Bitwise difference: 90
# Flipped bit index: 220, Bitwise difference: 103
# Flipped bit index: 221, Bitwise difference: 107
# Flipped bit index: 222, Bitwise difference: 106
# Flipped bit index: 223, Bitwise difference: 95
# Flipped bit index: 224, Bitwise difference: 96
# Flipped bit index: 225, Bitwise difference: 94
# Flipped bit index: 226, Bitwise difference: 95
# Flipped bit index: 227, Bitwise difference: 97
# Flipped bit index: 228, Bitwise difference: 103
# Flipped bit index: 229, Bitwise difference: 94
# Flipped bit index: 230, Bitwise difference: 99
# Flipped bit index: 231, Bitwise difference: 97
# Flipped bit index: 232, Bitwise difference: 92
# Flipped bit index: 233, Bitwise difference: 102
# Flipped bit index: 234, Bitwise difference: 96
# Flipped bit index: 235, Bitwise difference: 104
# Flipped bit index: 236, Bitwise difference: 103
# Flipped bit index: 237, Bitwise difference: 107
# Flipped bit index: 238, Bitwise difference: 98
# Flipped bit index: 239, Bitwise difference: 94
# Flipped bit index: 240, Bitwise difference: 103
# Flipped bit index: 241, Bitwise difference: 105
# Flipped bit index: 242, Bitwise difference: 100
# Flipped bit index: 243, Bitwise difference: 107
# Flipped bit index: 244, Bitwise difference: 104
# Flipped bit index: 245, Bitwise difference: 94
# Flipped bit index: 246, Bitwise difference: 94
# Flipped bit index: 247, Bitwise difference: 114
# Flipped bit index: 248, Bitwise difference: 98
# Flipped bit index: 249, Bitwise difference: 93
# Flipped bit index: 250, Bitwise difference: 106
# Flipped bit index: 251, Bitwise difference: 110
# Flipped bit index: 252, Bitwise difference: 95
# Flipped bit index: 253, Bitwise difference: 93
# Flipped bit index: 254, Bitwise difference: 103
# Flipped bit index: 255, Bitwise difference: 94

# %% [markdown]
# # **Task 3: Effect of Plaintext Variations**
# - Use a fixed key and encrypt multiple plaintexts with minor variations.
#
# - Compare ciphertexts and analyze the impact of plaintext modifications on encryption
# results.

# %%
key = get_random_bytes(32)
nonce = get_random_bytes(12)

# Original plaintext
original_plaintext = b"This is a secret message."

# Encrypt the original plaintext
original_ciphertext = encrypt_chacha20(original_plaintext, key, nonce)

# Create variations of the plaintext
variations = [
    b"This is a secret message.",
    b"This is a secret message!!",
    b"This is a SECRET message.",
    b"This is a different message."
]

# Encrypt the variations and compare with the original ciphertext
for variation in variations:
  ciphertext_variation = encrypt_chacha20(variation, key, nonce)
  diff_count = sum(bin(a ^ b).count('1') for a, b in zip(original_ciphertext, ciphertext_variation))
  print(f"Plaintext variation: {variation}")
  print(f"Ciphertext difference from original (bitwise): {diff_count}")
  print("-" * 30)
# Out:
# Plaintext variation: b'This is a secret message.'
# Ciphertext difference from original (bitwise): 0
# ------------------------------
# Plaintext variation: b'This is a secret message!!'
# Ciphertext difference from original (bitwise): 4
# ------------------------------
# Plaintext variation: b'This is a SECRET message.'
# Ciphertext difference from original (bitwise): 6
# ------------------------------
# Plaintext variation: b'This is a different message.'
# Ciphertext difference from original (bitwise): 38
# ------------------------------

# %% [markdown]
# # **Task 4: Strength Analysis and Report**
# - Conduct a statistical analysis of ciphertexts to evaluate randomness (use entropy and
# frequency analysis).
# - Measure encryption and decryption time variations with increasing plaintext size.
# - Discuss the impact of key length and plaintext patterns on ChaCha20 security.
# - Compare ChaCha20 with RC4 and AES, explaining why ChaCha20 is considered secure.

# %%
import numpy as np
from collections import Counter

def calculate_entropy(data):
  """Calculates the Shannon entropy of a byte string."""
  value_counts = Counter(data)
  probabilities = [count / len(data) for count in value_counts.values()]
  entropy = -sum(p * np.log2(p) for p in probabilities)
  return entropy

# Generate random ciphertexts for analysis
key = get_random_bytes(32)
nonce = get_random_bytes(12)
plaintext_sizes = [1024, 4096, 16384]
ciphertexts = []

for size in plaintext_sizes:
  plaintext = get_random_bytes(size)
  ciphertext = encrypt_chacha20(plaintext, key, nonce)
  ciphertexts.append(ciphertext)


# Analyze entropy and frequency
for ciphertext in ciphertexts:
  entropy = calculate_entropy(ciphertext)
  byte_frequencies = Counter(ciphertext)

  print("Ciphertext Entropy:", entropy)
  print("Byte Frequency Analysis:", byte_frequencies)
  print("-" * 30)


# Analyze encryption and decryption time variations
plaintext_sizes = [1024, 4096, 16384, 65536]
encryption_times = []
decryption_times = []

for size in plaintext_sizes:
  plaintext = get_random_bytes(size)
  start_time = time.time()
  ciphertext = encrypt_chacha20(plaintext, key, nonce)
  end_time = time.time()
  encryption_times.append(end_time - start_time)

  start_time = time.time()
  decrypted_plaintext = decrypt_chacha20(ciphertext, key, nonce)
  end_time = time.time()
  decryption_times.append(end_time - start_time)

print("Plaintext Size vs. Encryption/Decryption Time")
for i in range(len(plaintext_sizes)):
  print(f"Size: {plaintext_sizes[i]}, Encryption Time: {encryption_times[i]:.6f}, Decryption Time: {decryption_times[i]:.6f}")

print("-" * 30)


# Discuss impact of key length and plaintext patterns
print("Key Length and Plaintext Patterns:")
print(
    "ChaCha20's security relies heavily on the key's randomness and length."
    "A 256-bit key provides excellent security against brute-force attacks."
    "Plaintext patterns can potentially weaken the encryption if they are predictable."
    "ChaCha20's design aims to resist such attacks through its strong diffusion and confusion properties."
)
print("-" * 30)


# Compare with RC4 and AES
print("Comparison with RC4 and AES:")
print(
    "RC4 is considered insecure due to known vulnerabilities related to bias in the keystream. "
    "AES is a widely used and strong block cipher. ChaCha20 is considered secure because it is a stream cipher with strong design and proven resistance against known attacks. "
    "It offers advantages such as performance and flexibility, especially in situations where processing blocks isn't efficient."
)
# Out:
# Ciphertext Entropy: 7.811869810353487
# Byte Frequency Analysis: Counter({210: 9, 143: 9, 156: 9, 189: 9, 105: 8, 59: 8, 218: 8, 128: 8, 86: 8, 9: 8, 229: 8, 197: 8, 22: 8, 238: 8, 224: 7, 226: 7, 252: 7, 173: 7, 5: 7, 253: 7, 97: 7, 34: 7, 29: 7, 65: 7, 33: 7, 76: 7, 248: 7, 142: 6, 4: 6, 176: 6, 79: 6, 36: 6, 30: 6, 54: 6, 227: 6, 100: 6, 118: 6, 167: 6, 89: 6, 164: 6, 165: 6, 6: 6, 25: 6, 63: 6, 103: 6, 11: 6, 240: 6, 43: 6, 13: 6, 132: 6, 212: 6, 193: 6, 71: 6, 184: 6, 155: 6, 110: 6, 117: 6, 19: 6, 45: 6, 181: 5, 56: 5, 175: 5, 75: 5, 82: 5, 230: 5, 122: 5, 154: 5, 133: 5, 74: 5, 40: 5, 153: 5, 62: 5, 27: 5, 177: 5, 161: 5, 239: 5, 236: 5, 14: 5, 90: 5, 141: 5, 24: 5, 247: 5, 228: 5, 217: 5, 148: 5, 49: 5, 206: 5, 179: 5, 126: 5, 223: 5, 67: 5, 106: 5, 51: 5, 204: 5, 151: 5, 95: 5, 111: 5, 18: 5, 152: 4, 205: 4, 233: 4, 221: 4, 61: 4, 81: 4, 120: 4, 168: 4, 23: 4, 42: 4, 149: 4, 112: 4, 83: 4, 44: 4, 139: 4, 46